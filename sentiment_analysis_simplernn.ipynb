# %% [markdown]
# <a href="https://colab.research.google.com/github/radhikarajput0410-wq/Perceptron-Basics/blob/main/sentiment_analysis_simplernn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

docs = ['go india',
		'india india',
		'hip hip hurray',
		'jeetega bhai jeetega india jeetega',
		'bharat mata ki jai',
		'kohli kohli',
		'sachin sachin',
		'dhoni dhoni',
		'modi ji ki jai',
		'inquilab zindabad']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)
# Out:
# 17

# %%
sequences=tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[9, 1],
#  [1, 1],
#  [3, 3, 10],
#  [2, 11, 2, 1, 2],
#  [12, 13, 4, 5],
#  [6, 6],
#  [7, 7],
#  [8, 8],
#  [14, 15, 4, 5],
#  [16, 17]]

# %%
from keras.utils import pad_sequences
sequences=pad_sequences(sequences,padding='post')
sequences
# Out:
# array([[ 9,  1,  0,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 3,  3, 10,  0,  0],
#        [ 2, 11,  2,  1,  2],
#        [12, 13,  4,  5,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [14, 15,  4,  5,  0],
#        [16, 17,  0,  0,  0]], dtype=int32)

# %%
from keras import Sequential
from keras.layers import Dense, SimpleRNN,Embedding,Flatten

# %%
model=Sequential()
vocab_size = len(tokenizer.word_index) + 1
model.add(Embedding(input_dim=vocab_size,
                    output_dim=32))

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam','accuracy')

# %%
pred =model.predict(sequences)
print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# [[[ 0.02283825 -0.01903255 -0.04795524 ... -0.01502787 -0.01105831
#    -0.00994253]
#   [-0.02854266  0.03578139  0.04398272 ... -0.04480336  0.02999196
#    -0.00321241]
#   [-0.03389498  0.01745291 -0.04733017 ...  0.04719291  0.02454797
#    -0.04800782]
#   [-0.03389498  0.01745291 -0.04733017 ...  0.04719291  0.02454797
#    -0.04800782]
#   [-0.03389498  0.01745291 -0.04733017 ...  0.04719291  0.02454797
#    -0.04800782]]
#
#  [[-0.02854266  0.03578139  0.04398272 ... -0.04480336  0.02999196
#    -0.00321241]
#   [-0.02854266  0.03578139  0.04398272 ... -0.04480336  0.02999196
#    -0.00321241]
#   [-0.03389498  0.01745291 -0.04733017 ...  0.04719291  0.02454797
#    -0.04800782]
#   [-0.03389498  0.01745291 -0.04733017 ...  0.04719291  0.02454797
#    -0.04800782]
#   [-0.03389498  0.01745291 -0.04733017 ...  0.04719291  0.02454797
#    -0.04800782]]
#
#  [[ 0.0441541  -0.01495577  0.04055221 ... -0.03960673 -0.01283116
# ...
